# %%
import pandas as pd
import numpy as np
import datetime
from time import strftime
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
basedata = pd.read_csv('data.csv')
basedata.head() # Displaying the first few rows of the dataset
# Out:
#       PatientId  AppointmentID Gender          ScheduledDay  \
# 0  2.987250e+13        5642903      F  2016-04-29T18:38:08Z
# 1  5.589978e+14        5642503      M  2016-04-29T16:08:27Z
# 2  4.262962e+12        5642549      F  2016-04-29T16:19:04Z
# 3  8.679512e+11        5642828      F  2016-04-29T17:29:31Z
# 4  8.841186e+12        5642494      F  2016-04-29T16:07:23Z
#
#          AppointmentDay  Age      Neighbourhood  Scholarship  Hipertension  \
# 0  2016-04-29T00:00:00Z   62    JARDIM DA PENHA            0             1
# 1  2016-04-29T00:00:00Z   56    JARDIM DA PENHA            0             0
# 2  2016-04-29T00:00:00Z   62      MATA DA PRAIA            0             0
# 3  2016-04-29T00:00:00Z    8  PONTAL DE CAMBURI            0             0
# 4  2016-04-29T00:00:00Z   56    JARDIM DA PENHA            0             1
#
#    Diabetes  Alcoholism  Handcap  SMS_received No-show
# 0         0           0        0             0      No
# ...

# %%
basedata.tail() # Displaying the first few rows of the dataset
# Out:
#            PatientId  AppointmentID Gender          ScheduledDay  \
# 110522  2.572134e+12        5651768      F  2016-05-03T09:15:35Z
# 110523  3.596266e+12        5650093      F  2016-05-03T07:27:33Z
# 110524  1.557663e+13        5630692      F  2016-04-27T16:03:52Z
# 110525  9.213493e+13        5630323      F  2016-04-27T15:09:23Z
# 110526  3.775115e+14        5629448      F  2016-04-27T13:30:56Z
#
#               AppointmentDay  Age Neighbourhood  Scholarship  Hipertension  \
# 110522  2016-06-07T00:00:00Z   56   MARIA ORTIZ            0             0
# 110523  2016-06-07T00:00:00Z   51   MARIA ORTIZ            0             0
# 110524  2016-06-07T00:00:00Z   21   MARIA ORTIZ            0             0
# 110525  2016-06-07T00:00:00Z   38   MARIA ORTIZ            0             0
# 110526  2016-06-07T00:00:00Z   54   MARIA ORTIZ            0             0
#
#         Diabetes  Alcoholism  Handcap  SMS_received No-show
# 110522         0           0        0             1      No
# ...

# %%
basedata.info() # Displaying the first few rows of the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110527 entries, 0 to 110526
# Data columns (total 14 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   PatientId       110527 non-null  float64
#  1   AppointmentID   110527 non-null  int64
#  2   Gender          110527 non-null  object
#  3   ScheduledDay    110527 non-null  object
#  4   AppointmentDay  110527 non-null  object
#  5   Age             110527 non-null  int64
#  6   Neighbourhood   110527 non-null  object
#  7   Scholarship     110527 non-null  int64
#  8   Hipertension    110527 non-null  int64
#  9   Diabetes        110527 non-null  int64
#  10  Alcoholism      110527 non-null  int64
#  11  Handcap         110527 non-null  int64
#  12  SMS_received    110527 non-null  int64
#  13  No-show         110527 non-null  object
# dtypes: float64(1), int64(8), object(5)
# memory usage: 11.8+ MB

# %%
basedata.describe() # Displaying the first few rows of the dataset
# Out:
#           PatientId  AppointmentID            Age    Scholarship  \
# count  1.105270e+05   1.105270e+05  110527.000000  110527.000000
# mean   1.474963e+14   5.675305e+06      37.088874       0.098266
# std    2.560949e+14   7.129575e+04      23.110205       0.297675
# min    3.921784e+04   5.030230e+06      -1.000000       0.000000
# 25%    4.172614e+12   5.640286e+06      18.000000       0.000000
# 50%    3.173184e+13   5.680573e+06      37.000000       0.000000
# 75%    9.439172e+13   5.725524e+06      55.000000       0.000000
# max    9.999816e+14   5.790484e+06     115.000000       1.000000
#
#         Hipertension       Diabetes     Alcoholism        Handcap  \
# count  110527.000000  110527.000000  110527.000000  110527.000000
# mean        0.197246       0.071865       0.030400       0.022248
# std         0.397921       0.258265       0.171686       0.161543
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %%
basedata['ScheduledDay'] = pd.to_datetime(basedata['ScheduledDay']).dt.date.astype('datetime64[ns]')       # Converting ScheduledDay to datetime format
basedata['AppointmentDay'] = pd.to_datetime(basedata['AppointmentDay']).dt.date.astype('datetime64[ns]')       # Converting AppointmentDay to datetime format

# %%
basedata.head(10)   # Displaying the first 10 rows of the dataset
# Out:
#       PatientId  AppointmentID Gender ScheduledDay AppointmentDay  Age  \
# 0  2.987250e+13        5642903      F   2016-04-29     2016-04-29   62
# 1  5.589978e+14        5642503      M   2016-04-29     2016-04-29   56
# 2  4.262962e+12        5642549      F   2016-04-29     2016-04-29   62
# 3  8.679512e+11        5642828      F   2016-04-29     2016-04-29    8
# 4  8.841186e+12        5642494      F   2016-04-29     2016-04-29   56
# 5  9.598513e+13        5626772      F   2016-04-27     2016-04-29   76
# 6  7.336882e+14        5630279      F   2016-04-27     2016-04-29   23
# 7  3.449833e+12        5630575      F   2016-04-27     2016-04-29   39
# 8  5.639473e+13        5638447      F   2016-04-29     2016-04-29   21
# 9  7.812456e+13        5629123      F   2016-04-27     2016-04-29   19
#
#        Neighbourhood  Scholarship  Hipertension  Diabetes  Alcoholism  \
# 0    JARDIM DA PENHA            0             1         0           0
# ...

# %% [markdown]
# For the schedule day and appointment day storing the weekdays only into a variable

# %%
basedata['sch_weekday'] = basedata['ScheduledDay'].dt.dayofweek   # Extracting the day of the week from ScheduledDay
basedata['app_weekday'] = basedata['AppointmentDay'].dt.dayofweek  # Extracting the day of the week from AppointmentDay

# %%
basedata['sch_weekday'].value_counts()   # Counting the occurrences of each day of the week in where 0 means Monday and 6 means Sunday
# Out:
# sch_weekday
# 1    26168
# 2    24262
# 0    23085
# 4    18915
# 3    18073
# 5       24
# Name: count, dtype: int64

# %%
basedata['app_weekday'].value_counts()   # Counting the occurrences of each day of the week in AppointmentDay
# Out:
# app_weekday
# 2    25867
# 1    25640
# 0    22715
# 4    19019
# 3    17247
# 5       39
# Name: count, dtype: int64

# %%
#no sunday appointments
basedata['app_weekday'].value_counts().plot(kind='bar', figsize=(10, 5), color='skyblue', edgecolor='black')
plt.title('Number of Appointments by Day of the Week')
plt.xlabel('Day of the Week (0=Monday, 6=Sunday)')
plt.ylabel('Number of Appointments')
plt.xticks(rotation=0)
plt.show()

# %%
basedata.columns
# Out:
# Index(['PatientId', 'AppointmentID', 'Gender', 'ScheduledDay',
#        'AppointmentDay', 'Age', 'Neighbourhood', 'Scholarship', 'Hipertension',
#        'Diabetes', 'Alcoholism', 'Handcap', 'SMS_received', 'No-show',
#        'sch_weekday', 'app_weekday'],
#       dtype='object')

# %%
# Renaming columns for consistency
basedata = basedata.rename(columns={'Hipertension': 'Hypertension', 'Handcap': 'Handicap', 'No-show': 'NoShow', 'SMS_received': 'SMSReceived', 'PatientId': 'PatientID', 'AppointmentID': 'AppointmentID'})

# %%
basedata.columns # Displaying the first few rows of the dataset after renaming columns
# Out:
# Index(['PatientID', 'AppointmentID', 'Gender', 'ScheduledDay',
#        'AppointmentDay', 'Age', 'Neighbourhood', 'Scholarship', 'Hypertension',
#        'Diabetes', 'Alcoholism', 'Handicap', 'SMSReceived', 'NoShow',
#        'sch_weekday', 'app_weekday'],
#       dtype='object')

# %%
basedata.info() # Displaying the first few rows of the dataset after renaming columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110527 entries, 0 to 110526
# Data columns (total 16 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   PatientID       110527 non-null  float64
#  1   AppointmentID   110527 non-null  int64
#  2   Gender          110527 non-null  object
#  3   ScheduledDay    110527 non-null  datetime64[ns]
#  4   AppointmentDay  110527 non-null  datetime64[ns]
#  5   Age             110527 non-null  int64
#  6   Neighbourhood   110527 non-null  object
#  7   Scholarship     110527 non-null  int64
#  8   Hypertension    110527 non-null  int64
#  9   Diabetes        110527 non-null  int64
#  10  Alcoholism      110527 non-null  int64
#  11  Handicap        110527 non-null  int64
#  12  SMSReceived     110527 non-null  int64
#  13  NoShow          110527 non-null  object
#  14  sch_weekday     110527 non-null  int32
#  15  app_weekday     110527 non-null  int32
# ...

# %%
# Dropping unnecessary columns
basedata.drop(columns=['PatientID', 'AppointmentID', 'Neighbourhood'], axis=1, inplace=True)

# %%
basedata.columns
# Out:
# Index(['Gender', 'ScheduledDay', 'AppointmentDay', 'Age', 'Scholarship',
#        'Hypertension', 'Diabetes', 'Alcoholism', 'Handicap', 'SMSReceived',
#        'NoShow', 'sch_weekday', 'app_weekday'],
#       dtype='object')

# %%
basedata
# Out:
#        Gender ScheduledDay AppointmentDay  Age  Scholarship  Hypertension  \
# 0           F   2016-04-29     2016-04-29   62            0             1
# 1           M   2016-04-29     2016-04-29   56            0             0
# 2           F   2016-04-29     2016-04-29   62            0             0
# 3           F   2016-04-29     2016-04-29    8            0             0
# 4           F   2016-04-29     2016-04-29   56            0             1
# ...       ...          ...            ...  ...          ...           ...
# 110522      F   2016-05-03     2016-06-07   56            0             0
# 110523      F   2016-05-03     2016-06-07   51            0             0
# 110524      F   2016-04-27     2016-06-07   21            0             0
# 110525      F   2016-04-27     2016-06-07   38            0             0
# 110526      F   2016-04-27     2016-06-07   54            0             0
#
#         Diabetes  Alcoholism  Handicap  SMSReceived NoShow  sch_weekday  \
# ...

# %%
basedata.info() # Displaying the first few rows of the dataset after renaming columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110527 entries, 0 to 110526
# Data columns (total 13 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Gender          110527 non-null  object
#  1   ScheduledDay    110527 non-null  datetime64[ns]
#  2   AppointmentDay  110527 non-null  datetime64[ns]
#  3   Age             110527 non-null  int64
#  4   Scholarship     110527 non-null  int64
#  5   Hypertension    110527 non-null  int64
#  6   Diabetes        110527 non-null  int64
#  7   Alcoholism      110527 non-null  int64
#  8   Handicap        110527 non-null  int64
#  9   SMSReceived     110527 non-null  int64
#  10  NoShow          110527 non-null  object
#  11  sch_weekday     110527 non-null  int32
#  12  app_weekday     110527 non-null  int32
# dtypes: datetime64[ns](2), int32(2), int64(7), object(2)
# memory usage: 10.1+ MB

# %%
basedata.describe() # Displaying the first few rows of the dataset
# Out:
#                         ScheduledDay                 AppointmentDay  \
# count                         110527                         110527
# mean   2016-05-08 20:33:18.179630080  2016-05-19 00:57:50.008233472
# min              2015-11-10 00:00:00            2016-04-29 00:00:00
# 25%              2016-04-29 00:00:00            2016-05-09 00:00:00
# 50%              2016-05-10 00:00:00            2016-05-18 00:00:00
# 75%              2016-05-20 00:00:00            2016-05-31 00:00:00
# max              2016-06-08 00:00:00            2016-06-08 00:00:00
# std                              NaN                            NaN
#
#                  Age    Scholarship   Hypertension       Diabetes  \
# count  110527.000000  110527.000000  110527.000000  110527.000000
# mean       37.088874       0.098266       0.197246       0.071865
# min        -1.000000       0.000000       0.000000       0.000000
# 25%        18.000000       0.000000       0.000000       0.000000
# ...

# %%
basedata['NoShow'].value_counts() # Counting the occurrences of NoShow values
# Out:
# NoShow
# No     88208
# Yes    22319
# Name: count, dtype: int64

# %%
basedata['NoShow'].value_counts()
# Plotting the distribution of NoShow values
# Out:
# NoShow
# No     88208
# Yes    22319
# Name: count, dtype: int64

# %%
# Plotting the distribution of NoShow values
basedata['NoShow'].value_counts().plot(kind='barh', figsize=(8, 6)) 
plt.xlabel('Count', labelpad=14)
plt.ylabel('Target Variable', labelpad=4)
plt.title('Count of Target Variable per Category', y=1.02)
# Out:
# Text(0.5, 1.02, 'Count of Target Variable per Category')

# %%
# Plotting the distribution of NoShow values
100*basedata['NoShow'].value_counts() / len(basedata['NoShow'])
# Out:
# NoShow
# No     79.806744
# Yes    20.193256
# Name: count, dtype: float64

# %% [markdown]
# ##Our inference is that it is highly imbalance data we can clearly see that it has around 80% No

# %%
# Having a look that data contains missing values or not
missing = pd.DataFrame((basedata.isnull().sum())*100/basedata.shape[0]).reset_index()
plt.figure(figsize=(16,5))
ax = sns.pointplot(x='index', y=0, data=missing)
plt.xticks(rotation =90,fontsize =7)
plt.title("Percentage of Missing values")
plt.ylabel("PERCENTAGE")
plt.show()

# %%
missing = pd.DataFrame((basedata.isnull().sum()) * 100 / basedata.shape[0]).reset_index()
missing.columns = ['Column', 'MissingPercent']

plt.figure(figsize=(16,5))
ax = sns.pointplot(x='Column', y='MissingPercent', data=missing)
plt.xticks(rotation=90, fontsize=7)
plt.title("Percentage of Missing Values")
# Out:
# Text(0.5, 1.0, 'Percentage of Missing Values')

# %% [markdown]
# ## Missing Data - Initial Intuition
#
# Here, we don't have any missing data.
# General Thumb Rules:
#
# For features with less missing values- can use regression to predict the missing values or fill with the mean of the values present, depending on the feature.
#
# For features with very high number of missing values- it is better to drop those columns as they give very less insight on analysis.
#
# As there's no thumb rule on what criteria do we delete the columns with high number of missing values, but generally you can delete the columns, if you have more than 30-40% of missing values.

# %% [markdown]
# ## Data Cleaning
#
# Create a copy of base data for manupulation & processing

# %%
new_data = basedata.copy()

# %%
new_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110527 entries, 0 to 110526
# Data columns (total 13 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Gender          110527 non-null  object
#  1   ScheduledDay    110527 non-null  datetime64[ns]
#  2   AppointmentDay  110527 non-null  datetime64[ns]
#  3   Age             110527 non-null  int64
#  4   Scholarship     110527 non-null  int64
#  5   Hypertension    110527 non-null  int64
#  6   Diabetes        110527 non-null  int64
#  7   Alcoholism      110527 non-null  int64
#  8   Handicap        110527 non-null  int64
#  9   SMSReceived     110527 non-null  int64
#  10  NoShow          110527 non-null  object
#  11  sch_weekday     110527 non-null  int32
#  12  app_weekday     110527 non-null  int32
# dtypes: datetime64[ns](2), int32(2), int64(7), object(2)
# memory usage: 10.1+ MB

# %%
# Get the max tenure
print(basedata['Age'].max()) #72
# Out:
# 115

# %%
# Group the tenure in bins of 12 months
labels = ["{0} - {1}".format(i, i + 20) for i in range(1, 118, 20)]
basedata['Age_group'] = pd.cut(basedata.Age, range(1, 130, 20), right=False, labels=labels)

# %%
basedata.drop(['Age'], axis=1, inplace=True)

# %% [markdown]
# ## Data Exploration

# %%
list(basedata.columns)
# Out:
# ['Gender',
#  'ScheduledDay',
#  'AppointmentDay',
#  'Scholarship',
#  'Hypertension',
#  'Diabetes',
#  'Alcoholism',
#  'Handicap',
#  'SMSReceived',
#  'NoShow',
#  'sch_weekday',
#  'app_weekday',
#  'Age_group']

# %%
#having a loook into the values of count of each columns and there count in respect to NoShow column
for i, predictor in enumerate(basedata.drop(columns=['NoShow'])):
    print('-'*10,predictor,'-'*10)
    print(basedata[predictor].value_counts())    
    plt.figure(i)
    sns.countplot(data=basedata, x=predictor, hue='NoShow')
# Out:
# ---------- Gender ----------
# Gender
# F    71840
# M    38687
# Name: count, dtype: int64
# ---------- ScheduledDay ----------
# ScheduledDay
# 2016-05-03    4238
# 2016-05-02    4216
# 2016-05-16    4120
# 2016-05-05    4095
# 2016-05-10    4024
#               ...
# 2016-04-16       1
# 2016-01-28       1
# 2015-11-10       1
# 2016-03-19       1
# 2016-03-05       1
# Name: count, Length: 111, dtype: int64
# ---------- AppointmentDay ----------
# AppointmentDay
# 2016-06-06    4692
# 2016-05-16    4613
# 2016-05-09    4520
# 2016-05-30    4514
# 2016-06-08    4479
# 2016-05-11    4474
# 2016-06-01    4464
# 2016-06-07    4416
# 2016-05-12    4394
# 2016-05-02    4376
# 2016-05-18    4373
# 2016-05-17    4372
# 2016-06-02    4310
# 2016-05-10    4308
# 2016-05-31    4279
# 2016-05-05    4273
# 2016-05-19    4270
# 2016-05-03    4256
# 2016-05-04    4168
# 2016-06-03    4090
# 2016-05-24    4009
# 2016-05-13    3987
# 2016-05-25    3909
# 2016-05-06    3879
# 2016-05-20    3828
# ...

# %%
basedata['NoShow'] = np.where(basedata.NoShow == 'Yes',1,0)

# %%
basedata.NoShow.value_counts()
# Out:
# NoShow
# 0    88208
# 1    22319
# Name: count, dtype: int64

# %%
base_data_dummies = pd.get_dummies(basedata)
base_data_dummies.head()
# Out:
#   ScheduledDay AppointmentDay  Scholarship  Hypertension  Diabetes  \
# 0   2016-04-29     2016-04-29            0             1         0
# 1   2016-04-29     2016-04-29            0             0         0
# 2   2016-04-29     2016-04-29            0             0         0
# 3   2016-04-29     2016-04-29            0             0         0
# 4   2016-04-29     2016-04-29            0             1         1
#
#    Alcoholism  Handicap  SMSReceived  NoShow  sch_weekday  app_weekday  \
# 0           0         0            0       0            4            4
# 1           0         0            0       0            4            4
# 2           0         0            0       0            4            4
# 3           0         0            0       0            4            4
# 4           0         0            0       0            4            4
#
#    Gender_F  Gender_M  Age_group_1 - 21  Age_group_21 - 41  Age_group_41 - 61  \
# ...

# %% [markdown]
# Build a corelation of all predictors with 'NoShow'

# %%
plt.figure(figsize=(20,8))
base_data_dummies.corr()['NoShow'].sort_values(ascending = False).plot(kind='bar')
# Out:
# <Axes: >

# %%
plt.figure(figsize=(12,12))
sns.heatmap(base_data_dummies.corr(), cmap="coolwarm", annot=True, fmt=".2f", linewidths=0.5, linecolor='black')
# Out:
# <Axes: >

# %% [markdown]
# ## Bivariate Analysis

# %%
new_df1_target0=basedata.loc[basedata["NoShow"]==0]
new_df1_target1=basedata.loc[basedata ["NoShow"]==1]

# %%
def uniplot(df,col,title,hue =None):
    
    sns.set_style('whitegrid')
    sns.set_context('talk')
    plt.rcParams["axes.labelsize"] = 20
    plt.rcParams['axes.titlesize'] = 22
    plt.rcParams['axes.titlepad'] = 30
    
    
    temp = pd.Series(data = hue)
    fig, ax = plt.subplots()
    width = len(df[col].unique()) + 7 + 4*len(temp.unique())
    fig.set_size_inches(width , 8)
    plt.xticks(rotation=45)
    plt.yscale('log')
    plt.title(title)
    ax = sns.countplot(data = df, x= col, order=df[col].value_counts().index,hue = hue,palette='bright') 
        
    plt.show()

# %%
uniplot(new_df1_target0, 'Age_group', 'Age Group Distribution for No Show = 0', hue='NoShow')
uniplot(new_df1_target1, 'Age_group', 'Age Group Distribution for No Show = 1', hue='NoShow')

# %%
uniplot(new_df1_target1,col='Hypertension',title='Distribution of Gender for NoShow Customers',hue='Gender')
uniplot(new_df1_target0,col='Hypertension',title='Distribution of Gender for NoShow Customers',hue='Gender')

# %%
uniplot(new_df1_target0,col='Hypertension',title='Distribution of Gender for NoShow Customers',hue='Gender')
uniplot(new_df1_target1,col='Handicap',title='Distribution of Handicap for NoShow Customers',hue='NoShow')
uniplot(new_df1_target0,col='Handicap',title='Distribution of Handicap for NoShow Customers',hue='NoShow')
uniplot(new_df1_target1,col='Handicap',title='Distribution of Handicap for NoShow Customers',hue='NoShow')
uniplot(new_df1_target0,col='Handicap',title='Distribution of Handicap for NoShow Customers',hue='NoShow')

# %%
uniplot(new_df1_target1,col='Age_group',title='Distribution of Age for NoShow Customers',hue='Gender')
uniplot(new_df1_target0,col='Age_group',title='Distribution of Age for NoShow Customers',hue='Gender')

# %%
uniplot(new_df1_target0,col='Age_group',title='Distribution of Age for NoShow Customers',hue='Gender')
uniplot(new_df1_target1,col='Age_group',title='Distribution of Age for NoShow Customers',hue='Gender')

# %% [markdown]
# ## Findings
#
# Female patients have taken more appointments then male patients
#
# Ratio of Nohow and Show is almost equal for age group except Age 0 and Age 1 with 80% show rate for each age group
#
# Each Neighbourhood have almost 80% show rate
#
# There are 99666 patients without Scholarship and out of them around 80% have come for the visit and out of the 21801 patients with Scholarship around 75% of them
# have come for the visit.
#
# there are around 88,726 patients without Hypertension and out of them around 78% have come for the visit and Out of the 21801 patients with Hypertension around 85% of them have come for the visit.
#
# there are around 102,584 patients without Diabetes and out of them around 80% have come for the visit and Out of the 7,943 patients with Diabetes around 83% of them have come for the visit.
#
# there are around 75,045 patients who have not received SMS and out of them around 84% have come for the visit and out of the 35,482 patients who have received SMS around 72% of them have come for the visit.
#
# there is no appointments on sunday and on saturday appointments are very less in comparision to other week days
